# %% [markdown]
# <a href="https://colab.research.google.com/github/bertologabriela/meuportfolio/blob/main/Raspador_telecom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Folha

# %%
import requests
from bs4 import BeautifulSoup
requisicao = requests.get('https://www1.folha.uol.com.br/tec/')

import pandas as pd

# %%
#titulos1

# %%
html = requisicao.content
sopa = BeautifulSoup(html)

# %%
titulos = sopa.find_all('h2', {'class': 'c-headline__title'})

# %%
titulos_raspados = []

for titulo in titulos[:5]:
  titulos_raspados.append(titulo.text.strip())
print(titulos_raspados)
# Out:
# ['Acordo de US$ 1 bi da OpenAI com a Disney vai impulsionar o app de vídeos Sora?', 'Aplicativo Celular Seguro passa a permitir bloqueio de aparelho mesmo sem cadastro prévio', 'Como a Nvidia convenceu Trump a liberar venda de chip avançado para a China', 'Repórter do New York Times processa Google e OpenAI por uso indevido de livros', 'Startups de IA captam US$ 150 bilhões em meio a temores de bolha']

# %%
df_titulos = pd.DataFrame({'Titulo': titulos_raspados})
df_titulos
# Out:
#                                               Titulo
# 0  Acordo de US$ 1 bi da OpenAI com a Disney vai ...
# 1  Aplicativo Celular Seguro passa a permitir blo...
# 2  Como a Nvidia convenceu Trump a liberar venda ...
# 3  Repórter do New York Times processa Google e O...
# 4  Startups de IA captam US$ 150 bilhões em meio ...

# %%
#links1

# %%
links_raspados = []

for div in sopa.find_all('div', {'class': 'c-headline__content'})[:5]:
    a_tag = div.find('a')  # pega a <a> dentro da div
    if a_tag and 'href' in a_tag.attrs:
        links_raspados.append(a_tag['href'])

print(links_raspados)
# Out:
# ['https://www1.folha.uol.com.br/tec/2025/12/acordo-de-us-1-bi-da-openai-com-a-disney-vai-impulsionar-o-app-de-videos-sora.shtml', 'https://www1.folha.uol.com.br/tec/2025/12/aplicativo-celular-seguro-passa-a-permitir-bloqueio-de-aparelho-mesmo-sem-cadastro-previo.shtml', 'https://www1.folha.uol.com.br/tec/2025/12/como-a-nvidia-convenceu-trump-a-liberar-venda-de-chip-avancado-para-a-china.shtml', 'https://www1.folha.uol.com.br/mercado/2025/12/reporter-do-new-york-times-processa-google-e-openai-por-uso-indevido-de-livros.shtml', 'https://www1.folha.uol.com.br/mercado/2025/12/startups-de-ia-captam-us-150-bilhoes-em-meio-a-temores-de-bolha.shtml']

# %%
df_links = pd.DataFrame({'Link': links_raspados})
df_links
# Out:
#                                                 Link
# 0  https://www1.folha.uol.com.br/tec/2025/12/acor...
# 1  https://www1.folha.uol.com.br/tec/2025/12/apli...
# 2  https://www1.folha.uol.com.br/tec/2025/12/como...
# 3  https://www1.folha.uol.com.br/mercado/2025/12/...
# 4  https://www1.folha.uol.com.br/mercado/2025/12/...

# %%
#df final 1

# %%
#df 1

# %%
df_final_folha = pd.concat([df_titulos, df_links], axis=1)
df_final_folha['Veículo'] = 'Folha'
df_final_folha
# Out:
#                                               Titulo  \
# 0  Acordo de US$ 1 bi da OpenAI com a Disney vai ...
# 1  Aplicativo Celular Seguro passa a permitir blo...
# 2  Como a Nvidia convenceu Trump a liberar venda ...
# 3  Repórter do New York Times processa Google e O...
# 4  Startups de IA captam US$ 150 bilhões em meio ...
#
#                                                 Link Veículo
# 0  https://www1.folha.uol.com.br/tec/2025/12/acor...   Folha
# 1  https://www1.folha.uol.com.br/tec/2025/12/apli...   Folha
# 2  https://www1.folha.uol.com.br/tec/2025/12/como...   Folha
# 3  https://www1.folha.uol.com.br/mercado/2025/12/...   Folha
# 4  https://www1.folha.uol.com.br/mercado/2025/12/...   Folha

# %% [markdown]
# ###TeleSíntese

# %%
requisicao2 = requests.get('https://telesintese.com.br/plantao-de-noticias/')

# %%
html2 = requisicao2.content
sopa2 = BeautifulSoup(html2)

# %%
#titulos 2

# %%
titulos2 = sopa2.find_all('h2', {'class': 'entry-title'})

# %%
titulos_raspados2 = []

for titulo in titulos2[:5]:
  titulos_raspados2.append(titulo.text.strip())
print(titulos_raspados2)
# Out:
# ['Telebras e Correios têm PDG 2026 aprovado com subsídios do Tesouro e operações de crédito', 'Correios apresentam plano de reestruturação e estudam abrir capital', 'Publicada Lei 15.320, que prorroga incentivos tributários para IoT até 2030', 'V.tal adquire Um Telecom', 'Claro assina termo único e encerra concessão fixa de longa distância']

# %%
titulos_raspados2
# Out:
# ['Telebras e Correios têm PDG 2026 aprovado com subsídios do Tesouro e operações de crédito',
#  'Correios apresentam plano de reestruturação e estudam abrir capital',
#  'Publicada Lei 15.320, que prorroga incentivos tributários para IoT até 2030',
#  'V.tal adquire Um Telecom',
#  'Claro assina termo único e encerra concessão fixa de longa distância']

# %%
df_titulos2 = pd.DataFrame({'Titulo': titulos_raspados2})
df_titulos2
# Out:
#                                               Titulo
# 0  Telebras e Correios têm PDG 2026 aprovado com ...
# 1  Correios apresentam plano de reestruturação e ...
# 2  Publicada Lei 15.320, que prorroga incentivos ...
# 3                           V.tal adquire Um Telecom
# 4  Claro assina termo único e encerra concessão f...

# %%
#links 2

# %%
links2 = sopa2.find_all('a', class_='ct-media-container')

links_raspados2 = []

for link in links2[:5]:
    href = link.get('href')
    if href:
        links_raspados2.append(href.strip())

print(links_raspados2)
# Out:
# ['https://telesintese.com.br/telebras-e-correios-tem-pdg-2026-aprovado-com-subsidios-do-tesouro-e-operacoes-de-credito/', 'https://telesintese.com.br/correios-apresentam-plano-integrado-para-recuperar-niveis-de-servico/', 'https://telesintese.com.br/publicada-lei-15-320-que-prorroga-incentivos-tributarios-para-iot-ate-2030/', 'https://telesintese.com.br/v-tal-adquire-um-telecom/', 'https://telesintese.com.br/claro-assina-termo-unico-e-encerra-concessao-fixa-de-longa-distancia/']

# %%
df_links2 = pd.DataFrame({'Link': links_raspados2})
df_links2
# Out:
#                                                 Link
# 0  https://telesintese.com.br/telebras-e-correios...
# 1  https://telesintese.com.br/correios-apresentam...
# 2  https://telesintese.com.br/publicada-lei-15-32...
# 3  https://telesintese.com.br/v-tal-adquire-um-te...
# 4  https://telesintese.com.br/claro-assina-termo-...

# %%
#df 2

# %%
df_final_telesintese = pd.concat([df_titulos2, df_links2], axis=1)
df_final_telesintese['Veículo'] = 'TeleSintese'
df_final_telesintese
# Out:
#                                               Titulo  \
# 0  Telebras e Correios têm PDG 2026 aprovado com ...
# 1  Correios apresentam plano de reestruturação e ...
# 2  Publicada Lei 15.320, que prorroga incentivos ...
# 3                           V.tal adquire Um Telecom
# 4  Claro assina termo único e encerra concessão f...
#
#                                                 Link      Veículo
# 0  https://telesintese.com.br/telebras-e-correios...  TeleSintese
# 1  https://telesintese.com.br/correios-apresentam...  TeleSintese
# 2  https://telesintese.com.br/publicada-lei-15-32...  TeleSintese
# 3  https://telesintese.com.br/v-tal-adquire-um-te...  TeleSintese
# 4  https://telesintese.com.br/claro-assina-termo-...  TeleSintese

# %% [markdown]
# ###Teletime

# %%
requisicao3 = requests.get('https://teletime.com.br/noticias/')

# %%
html3 = requisicao3.content
sopa3 = BeautifulSoup(html3)

# %%
#titulos 3

# %%
titulos3 = sopa3.find_all('h3', {'class': 'entry-title td-module-title'})

# %%
titulos_raspados3 = []

for titulo in titulos3[:5]:
  titulos_raspados3.append(titulo.text.strip())
print(titulos_raspados3)
# Out:
# ['V.tal adquire a Um Telecom', 'Lei que desonera dispositivos de IoT e satélites até 2030 é sancionada', 'Ibama classifica operação de antena e sistema de telecom como potencialmente poluidora', 'Anatel inicia consulta sobre requisitos técnicos a data centers críticos para telecom', 'Serede demite todos os 4,8 mil funcionários; sindicatos protestam']

# %%
df_titulos3 = pd.DataFrame({'Titulo': titulos_raspados3})
df_titulos3
# Out:
#                                               Titulo
# 0                         V.tal adquire a Um Telecom
# 1  Lei que desonera dispositivos de IoT e satélit...
# 2  Ibama classifica operação de antena e sistema ...
# 3  Anatel inicia consulta sobre requisitos técnic...
# 4  Serede demite todos os 4,8 mil funcionários; s...

# %%
#links3

# %%
links3 = sopa3.find_all('h3', class_='entry-title td-module-title')

links_raspados3 = []

for link in links3[:5]:
    a_tag = link.find('a')
    if a_tag and a_tag.get('href'):
        href = a_tag.get('href').strip()
        links_raspados3.append(href)

print(links_raspados3)
# Out:
# ['https://teletime.com.br/29/12/2025/v-tal-adquire-a-um-telecom/', 'https://teletime.com.br/29/12/2025/lei-que-desonera-dispositivos-de-iot-e-satelites-ate-2030-e-sancionada/', 'https://teletime.com.br/29/12/2025/ibama-classifica-operacao-de-antena-e-sistema-de-telecom-como-potencialmente-poluidora/', 'https://teletime.com.br/29/12/2025/anatel-inicia-consulta-sobre-requisitos-tecnicos-a-data-centers-criticos-para-telecom/', 'https://teletime.com.br/22/12/2025/serede-demite-todos-os-48-mil-funcionarios-sindicatos-protestam/']

# %%
df_links3 = pd.DataFrame({'Link': links_raspados3})
df_links3
# Out:
#                                                 Link
# 0  https://teletime.com.br/29/12/2025/v-tal-adqui...
# 1  https://teletime.com.br/29/12/2025/lei-que-des...
# 2  https://teletime.com.br/29/12/2025/ibama-class...
# 3  https://teletime.com.br/29/12/2025/anatel-inic...
# 4  https://teletime.com.br/22/12/2025/serede-demi...

# %%
#df 3

# %%
df_final_teletime = pd.concat([df_titulos3, df_links3], axis=1)
df_final_teletime['Veículo'] = 'Teletime'
df_final_teletime
# Out:
#                                               Titulo  \
# 0                         V.tal adquire a Um Telecom
# 1  Lei que desonera dispositivos de IoT e satélit...
# 2  Ibama classifica operação de antena e sistema ...
# 3  Anatel inicia consulta sobre requisitos técnic...
# 4  Serede demite todos os 4,8 mil funcionários; s...
#
#                                                 Link   Veículo
# 0  https://teletime.com.br/29/12/2025/v-tal-adqui...  Teletime
# 1  https://teletime.com.br/29/12/2025/lei-que-des...  Teletime
# 2  https://teletime.com.br/29/12/2025/ibama-class...  Teletime
# 3  https://teletime.com.br/29/12/2025/anatel-inic...  Teletime
# 4  https://teletime.com.br/22/12/2025/serede-demi...  Teletime

# %% [markdown]
# ###DF final

# %%
teste_df_final = pd.concat([df_final_folha, df_final_telesintese, df_final_teletime])
teste_df_final
# Out:
#                                               Titulo  \
# 0  Acordo de US$ 1 bi da OpenAI com a Disney vai ...
# 1  Aplicativo Celular Seguro passa a permitir blo...
# 2  Como a Nvidia convenceu Trump a liberar venda ...
# 3  Repórter do New York Times processa Google e O...
# 4  Startups de IA captam US$ 150 bilhões em meio ...
# 0  Telebras e Correios têm PDG 2026 aprovado com ...
# 1  Correios apresentam plano de reestruturação e ...
# 2  Publicada Lei 15.320, que prorroga incentivos ...
# 3                           V.tal adquire Um Telecom
# 4  Claro assina termo único e encerra concessão f...
# 0                         V.tal adquire a Um Telecom
# 1  Lei que desonera dispositivos de IoT e satélit...
# 2  Ibama classifica operação de antena e sistema ...
# 3  Anatel inicia consulta sobre requisitos técnic...
# 4  Serede demite todos os 4,8 mil funcionários; s...
#
#                                                 Link      Veículo
# ...

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

agora = datetime.now(ZoneInfo("America/Sao_Paulo"))

data = agora.strftime("%d-%m-%Y")
hora = agora.strftime("%H-%M")

nome_arquivo = f"planilha noticias - data {data} - {hora}.csv"

teste_df_final.to_csv(
    nome_arquivo,
    index=False
)
